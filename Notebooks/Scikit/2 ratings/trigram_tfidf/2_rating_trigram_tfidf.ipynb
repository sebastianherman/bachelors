# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, roc_curve

from sklearn import metrics

import contractions

import scikitplot as skplt
import matplotlib.pyplot as plt
# Out:
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
yelp_data_5k = pd.read_csv(r"C:\Users\sebas\Documents\School\bachelor-final\Dataset\PROCESSED_RESTAURANT_REVIEWS_5k.csv")

# %%
yelp_data_5k.head()
# Out:
#    Unnamed: 0                                      reviewContent  usefulCount  \
# 0           0  "'Check, Please." The bartender was unable to ...           18
# 1           1  "2 stars for disappointing food, one star for ...           14
# 2           2  "A Divine Dialogue" God: "Britton. Times up. T...           14
# 3           3  "A Place To Go When You Have Time" It was a mi...           13
# 4           4  "A Thaiphoon of Flavor" My First: I never enli...           27
#
#    coolCount  funnyCount  rating            restaurantID  \
# 0         11          25       1  VZHyAmdFDreQqL0BT-zdoA
# 1         10           7       3  tFcmrGLZNEymSnijoTPmqw
# 2         16          23       5  INvIaBFnAvGxzTXFWHzGvA
# 3         10          10       5  FySId5SjNhkrtPA5qktdxg
# 4         22          28       5  RgeMUiZncTs-VSHQLm0wNg
#
#                             reviewCleanWithStopwords  \
# 0  check please the bartender was unable to recom...
# 1  stars for disappointing food one star for grea...
# 2  divine dialogue god britton times up the world...
# 3  place to go when you have time it was misty br...
# 4  thaiphoon of flavor my first never enlisted in...
#
#                               reviewCleanNoStopwords  \
# 0  check please bartender unable recommend beer t...
# 1  stars disappointing food one star great servic...
# 2  divine dialogue god britton times world going ...
# 3  place go time misty breezy summer night friend...
# 4  thaiphoon flavor first never enlisted air forc...
#
#                             reviewCleanPorterStemmer  \
# 0  check pleas bartend unabl recommend beer tap t...
# 1  star disappoint food one star great servic rea...
# 2  divin dialogu god britton time world go end to...
# 3  place go time misti breezi summer night friend...
# 4  thaiphoon flavor first never enlist air forc a...
#
#                           reviewCleanSnowballStemmer  \
# 0  check pleas bartend unabl recommend beer tap t...
# 1  star disappoint food one star great servic rea...
# 2  divin dialogu god britton time world go end to...
# 3  place go time misti breezi summer night friend...
# 4  thaiphoon flavor first never enlist air forc a...
#
#                                reviewCleanLemmatized  \
# 0  check please bartender unable recommend beer t...
# 1  star disappoint food one star great service re...
# 2  divine dialogue god britton time world go end ...
# 3  place go time misty breezy summer night friend...
# 4  thaiphoon flavor first never enlist air force ...
#
#                                 reviewCleanLancaster
# 0  check pleas bartend un recommend beer tap tri ...
# 1  star disappoint food on star gre serv read iai...
# 2  divin dialog god britton tim world going end t...
# 3  plac go tim misty breezy sum night friend jere...
# 4  thaiphoon flav first nev enl air forc allow jo...

# %%
yelp_data_5k.rating.value_counts()
# Out:
# 2    1250
# 5    1179
# 1    1159
# 3    1130
# 4    1051
# Name: rating, dtype: int64

# %%
yelp_data_5k.isnull().values.any()
# Out:
# False

# %% [markdown]
# # Remove 3 stars, transform 1,2 to 0 and 4,5 to one

# %%
# Get names of indexes for which column rating has value 2
indexNamesRating3 = yelp_data_5k[ yelp_data_5k['rating'] == 3 ].index
 
# Delete these row indexes from dataFrame
yelp_data_5k.drop(indexNamesRating3, inplace=True)

# %%
yelp_data_5k.rating.value_counts()
# Out:
# 2    1250
# 5    1179
# 1    1159
# 4    1051
# Name: rating, dtype: int64

# %%
# transform 1 and 2 stars to rating 0 and 4 and 5 stars to rating 1
yelp_data_5k['rating'] = yelp_data_5k['rating'].apply(lambda x: 1 if x>3 else 0)

# %%
yelp_data_5k.rating.value_counts()
# Out:
# 0    2409
# 1    2230
# Name: rating, dtype: int64

# %% [markdown]
# # Allocating each text with its specific cleaning method to a variable

# %%
x_cleanWithStopwords = yelp_data_5k["reviewCleanWithStopwords"]
x_cleanNoStopwords = yelp_data_5k["reviewCleanNoStopwords"]
x_porterStemmer = yelp_data_5k["reviewCleanPorterStemmer"]
x_snowballStemmer = yelp_data_5k["reviewCleanSnowballStemmer"]
x_lemmatized = yelp_data_5k["reviewCleanLemmatized"]
x_lancaster = yelp_data_5k["reviewCleanLancaster"]

# %% [markdown]
# # Vectorisation

# %%
tf = TfidfVectorizer(ngram_range=(1,3), min_df=5).fit(x_cleanWithStopwords)
x_cleanWithStopwords = tf.transform(x_cleanWithStopwords)

tf = TfidfVectorizer(ngram_range=(1,3), min_df=5).fit(x_cleanNoStopwords)
x_cleanNoStopwords = tf.transform(x_cleanNoStopwords)

tf = TfidfVectorizer(ngram_range=(1,3), min_df=5).fit(x_porterStemmer)
x_porterStemmer = tf.transform(x_porterStemmer)

tf = TfidfVectorizer(ngram_range=(1,3), min_df=5).fit(x_snowballStemmer)
x_snowballStemmer = tf.transform(x_snowballStemmer)

tf = TfidfVectorizer(ngram_range=(1,3), min_df=5).fit(x_lemmatized)
x_lemmatized = tf.transform(x_lemmatized)

tf = TfidfVectorizer(ngram_range=(1,3), min_df=5).fit(x_lancaster)
x_lancaster = tf.transform(x_lancaster)

# %%
y = yelp_data_5k["rating"]

# %% [markdown]
# # Splitting the data for training and testing

# %%
x_train_cleanWithStopwords, x_test_cleanWithStopwords, y_train, y_test = train_test_split(x_cleanWithStopwords, y, test_size=0.2, random_state=50)

x_train_cleanNoStopwords, x_test_cleanNoStopwords, y_train, y_test = train_test_split(x_cleanNoStopwords, y, test_size=0.2, random_state=50)

x_train_porterStemmer, x_test_porterStemmer, y_train, y_test = train_test_split(x_porterStemmer, y, test_size=0.2, random_state=50)

x_train_snowballStemmer, x_test_snowballStemmer, y_train, y_test = train_test_split(x_snowballStemmer, y, test_size=0.2, random_state=50)

x_train_lemmatized, x_test_lemmatized, y_train, y_test = train_test_split(x_lemmatized, y, test_size=0.2, random_state=50)

x_train_lancaster, x_test_lancaster, y_train, y_test = train_test_split(x_lancaster, y, test_size=0.2, random_state=50)

# %% [markdown]
# # Models
# ## Multinomial Naive Bayes

# %%
# Multinomial Naive Bayes
from sklearn.naive_bayes import MultinomialNB

# WITH STOPWORDS #################################################################################################################

# initialization
mnb = MultinomialNB()
mnb.fit(x_train_cleanWithStopwords, y_train)

# predicting
prediction = mnb.predict(x_test_cleanWithStopwords)

# generating and printing confusion matrix
print("WITH STOPWORDS")
print("Confusion Matrix for Multinomial Naive Bayes:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_mnb_with_stopwords.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# WITHOUT STOPWORDS #################################################################################################################


# initialization
mnb = MultinomialNB()
mnb.fit(x_train_cleanNoStopwords, y_train)

# predicting
prediction = mnb.predict(x_test_cleanNoStopwords)

# generating and printing confusion matrix
print("WITHOUT STOPWORDS")
print("Confusion Matrix for Multinomial Naive Bayes:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_mnb_no_stopwords.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# PORTERSTEMMER #################################################################################################################


# initialization
mnb = MultinomialNB()
mnb.fit(x_train_porterStemmer, y_train)

# predicting
prediction = mnb.predict(x_test_porterStemmer)

# generating and printing confusion matrix
print("PORTERSTEMMER")
print("Confusion Matrix for Multinomial Naive Bayes:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_mnb_porterstemmer.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# SNOWBALLSTEMMER #################################################################################################################


# initialization
mnb = MultinomialNB()
mnb.fit(x_train_snowballStemmer, y_train)

# predicting
prediction = mnb.predict(x_test_snowballStemmer)

# generating and printing confusion matrix
print("SNOWBALLSTEMMER")
print("Confusion Matrix for Multinomial Naive Bayes:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_mnb_snowballstemmer.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# LEMMATIZED #################################################################################################################


# initialization
mnb = MultinomialNB()
mnb.fit(x_train_lemmatized, y_train)

# predicting
prediction = mnb.predict(x_test_lemmatized)

# generating and printing confusion matrix
print("LEMMATIZED")
print("Confusion Matrix for Multinomial Naive Bayes:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_mnb_lemmatized.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# LANCASTER #################################################################################################################


# initialization
mnb = MultinomialNB()
mnb.fit(x_train_lancaster, y_train)

# predicting
prediction = mnb.predict(x_test_lancaster)

# generating and printing confusion matrix
print("LANCASTER")
print("Confusion Matrix for Multinomial Naive Bayes:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_mnb_lancaster.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))
# Out:
# WITH STOPWORDS
# Confusion Matrix for Multinomial Naive Bayes:
# [[434  61]
#  [ 48 385]]
# Score: 88.25
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89       495
#            1       0.86      0.89      0.88       433
#
#    micro avg       0.88      0.88      0.88       928
#    macro avg       0.88      0.88      0.88       928
# weighted avg       0.88      0.88      0.88       928
#
# WITHOUT STOPWORDS
# Confusion Matrix for Multinomial Naive Bayes:
# [[440  55]
#  [ 41 392]]
# Score: 89.66
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90       495
#            1       0.88      0.91      0.89       433
#
#    micro avg       0.90      0.90      0.90       928
#    macro avg       0.90      0.90      0.90       928
# weighted avg       0.90      0.90      0.90       928
#
# PORTERSTEMMER
# Confusion Matrix for Multinomial Naive Bayes:
# [[438  57]
#  [ 42 391]]
# Score: 89.33
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.88      0.90       495
#            1       0.87      0.90      0.89       433
#
#    micro avg       0.89      0.89      0.89       928
#    macro avg       0.89      0.89      0.89       928
# weighted avg       0.89      0.89      0.89       928
#
# SNOWBALLSTEMMER
# Confusion Matrix for Multinomial Naive Bayes:
# [[438  57]
#  [ 40 393]]
# Score: 89.55
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90       495
#            1       0.87      0.91      0.89       433
#
#    micro avg       0.90      0.90      0.90       928
#    macro avg       0.89      0.90      0.90       928
# weighted avg       0.90      0.90      0.90       928
#
# LEMMATIZED
# Confusion Matrix for Multinomial Naive Bayes:
# [[439  56]
#  [ 43 390]]
# Score: 89.33
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90       495
#            1       0.87      0.90      0.89       433
#
#    micro avg       0.89      0.89      0.89       928
#    macro avg       0.89      0.89      0.89       928
# weighted avg       0.89      0.89      0.89       928
#
# LANCASTER
# Confusion Matrix for Multinomial Naive Bayes:
# [[436  59]
#  [ 38 395]]
# Score: 89.55
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90       495
#            1       0.87      0.91      0.89       433
#
#    micro avg       0.90      0.90      0.90       928
#    macro avg       0.89      0.90      0.90       928
# weighted avg       0.90      0.90      0.90       928

# %% [markdown]
# ## Random Forrest

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier

# WITH STOPWORDS #################################################################################################################

# initialization
rmf = RandomForestClassifier(n_estimators=200)
rmf.fit(x_train_cleanWithStopwords,y_train)

# predicting
prediction = rmf.predict(x_test_cleanWithStopwords)

# generating and printing confusion matrix
print("CLEANED WITH STOPWORDS")
print("Confusion Matrix for Random Forest Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_rmf_with_stopwords.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# WITHOUT STOPWORDS #################################################################################################################


# initialization
rmf = RandomForestClassifier(n_estimators=200)
rmf.fit(x_train_cleanNoStopwords,y_train)

# predicting
prediction = rmf.predict(x_test_cleanNoStopwords)

# generating and printing confusion matrix
print("WITHOUT STOPWORDS")
print("Confusion Matrix for Random Forest Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_rmf_no_stopwords.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# PORTERSTEMMER #################################################################################################################


# initialization
rmf = RandomForestClassifier(n_estimators=200)
rmf.fit(x_train_porterStemmer,y_train)

# predicting
prediction = rmf.predict(x_test_porterStemmer)

# generating and printing confusion matrix
print("PORTERSTEMMER")
print("Confusion Matrix for Random Forest Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_rmf_porterstemmer.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# SNOWBALLSTEMMER #################################################################################################################


# initialization
rmf = RandomForestClassifier(n_estimators=200)
rmf.fit(x_train_snowballStemmer,y_train)

# predicting
prediction = rmf.predict(x_test_snowballStemmer)

# generating and printing confusion matrix
print("SNOWBALLSTEMMER")
print("Confusion Matrix for Random Forest Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_rmf_snowballstemmer.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# LEMMATIZED #################################################################################################################


# initialization
rmf = RandomForestClassifier(n_estimators=200)
rmf.fit(x_train_lemmatized,y_train)

# predicting
prediction = rmf.predict(x_test_lemmatized)

# generating and printing confusion matrix
print("LEMMATIZED")
print("Confusion Matrix for Random Forest Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_rmf_lemmatized.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# LANCASTER #################################################################################################################


# initialization
rmf = RandomForestClassifier(n_estimators=200)
rmf.fit(x_train_lancaster,y_train)

# predicting
prediction = rmf.predict(x_test_lancaster)

# generating and printing confusion matrix
print("LANCASTER")
print("Confusion Matrix for Random Forest Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_rmf_lancaster.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))
# Out:
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# CLEANED WITH STOPWORDS
# Confusion Matrix for Random Forest Classifier:
# [[451  44]
#  [ 66 367]]
# Score: 88.15
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89       495
#            1       0.89      0.85      0.87       433
#
#    micro avg       0.88      0.88      0.88       928
#    macro avg       0.88      0.88      0.88       928
# weighted avg       0.88      0.88      0.88       928
#
# WITHOUT STOPWORDS
# Confusion Matrix for Random Forest Classifier:
# [[442  53]
#  [ 52 381]]
# Score: 88.69
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89       495
#            1       0.88      0.88      0.88       433
#
#    micro avg       0.89      0.89      0.89       928
#    macro avg       0.89      0.89      0.89       928
# weighted avg       0.89      0.89      0.89       928
#
# PORTERSTEMMER
# Confusion Matrix for Random Forest Classifier:
# [[439  56]
#  [ 50 383]]
# Score: 88.58
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.89      0.89       495
#            1       0.87      0.88      0.88       433
#
#    micro avg       0.89      0.89      0.89       928
#    macro avg       0.89      0.89      0.89       928
# weighted avg       0.89      0.89      0.89       928
#
# SNOWBALLSTEMMER
# Confusion Matrix for Random Forest Classifier:
# [[444  51]
#  [ 57 376]]
# Score: 88.36
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.90      0.89       495
#            1       0.88      0.87      0.87       433
#
#    micro avg       0.88      0.88      0.88       928
#    macro avg       0.88      0.88      0.88       928
# weighted avg       0.88      0.88      0.88       928
#
# LEMMATIZED
# Confusion Matrix for Random Forest Classifier:
# [[437  58]
#  [ 57 376]]
# Score: 87.61
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88       495
#            1       0.87      0.87      0.87       433
#
#    micro avg       0.88      0.88      0.88       928
#    macro avg       0.88      0.88      0.88       928
# weighted avg       0.88      0.88      0.88       928
#
# LANCASTER
# Confusion Matrix for Random Forest Classifier:
# [[439  56]
#  [ 48 385]]
# Score: 88.79
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.89      0.89       495
#            1       0.87      0.89      0.88       433
#
#    micro avg       0.89      0.89      0.89       928
#    macro avg       0.89      0.89      0.89       928
# weighted avg       0.89      0.89      0.89       928

# %% [markdown]
# ## Decision Tree

# %%
# Decision tree
from sklearn.tree import DecisionTreeClassifier

# WITH STOPWORDS #################################################################################################################

# initialization
dt = DecisionTreeClassifier()
dt.fit(x_train_cleanWithStopwords,y_train)

# predicting
prediction = dt.predict(x_test_cleanWithStopwords)
print("WITH STOPWORDS")
print("Confusion Matrix for Decision Tree:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_dt_with_stopwords.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# WITHOUT STOPWORDS #################################################################################################################

# initialization
dt = DecisionTreeClassifier()
dt.fit(x_train_cleanNoStopwords,y_train)

# predicting
prediction = dt.predict(x_test_cleanNoStopwords)
print("WITHOUT STOPWORDS")
print("Confusion Matrix for Decision Tree:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_dt_no_stopwords.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# PORTERSTEMMER #################################################################################################################

# initialization
dt = DecisionTreeClassifier()
dt.fit(x_train_porterStemmer,y_train)

# predicting
prediction = dt.predict(x_test_porterStemmer)
print("PORTERSTEMMER")
print("Confusion Matrix for Decision Tree:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_dt_porterstemmer.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# SNOWBALLSTEMMER #################################################################################################################

# initialization
dt = DecisionTreeClassifier()
dt.fit(x_train_snowballStemmer,y_train)

# predicting
prediction = dt.predict(x_test_snowballStemmer)
print("SNOWBALLSTEMMER")
print("Confusion Matrix for Decision Tree:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_dt_snowballstemmer.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# LEMMATIZED #################################################################################################################

# initialization
dt = DecisionTreeClassifier()
dt.fit(x_train_lemmatized,y_train)

# predicting
prediction = dt.predict(x_test_lemmatized)
print("LEMMATIZED")
print("Confusion Matrix for Decision Tree:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_dt_lemmatized.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# LANCASTER #################################################################################################################

# initialization
dt = DecisionTreeClassifier()
dt.fit(x_train_lancaster,y_train)

# predicting
prediction = dt.predict(x_test_lancaster)
print("LANCASTER")
print("Confusion Matrix for Decision Tree:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_dt_lancaster.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))
# Out:
# WITH STOPWORDS
# Confusion Matrix for Decision Tree:
# [[366 129]
#  [128 305]]
# Score: 72.31
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.74      0.74       495
#            1       0.70      0.70      0.70       433
#
#    micro avg       0.72      0.72      0.72       928
#    macro avg       0.72      0.72      0.72       928
# weighted avg       0.72      0.72      0.72       928
#
# WITHOUT STOPWORDS
# Confusion Matrix for Decision Tree:
# [[369 126]
#  [132 301]]
# Score: 72.2
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.75      0.74       495
#            1       0.70      0.70      0.70       433
#
#    micro avg       0.72      0.72      0.72       928
#    macro avg       0.72      0.72      0.72       928
# weighted avg       0.72      0.72      0.72       928
#
# PORTERSTEMMER
# Confusion Matrix for Decision Tree:
# [[385 110]
#  [121 312]]
# Score: 75.11
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.76      0.78      0.77       495
#            1       0.74      0.72      0.73       433
#
#    micro avg       0.75      0.75      0.75       928
#    macro avg       0.75      0.75      0.75       928
# weighted avg       0.75      0.75      0.75       928
#
# SNOWBALLSTEMMER
# Confusion Matrix for Decision Tree:
# [[358 137]
#  [123 310]]
# Score: 71.98
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.72      0.73       495
#            1       0.69      0.72      0.70       433
#
#    micro avg       0.72      0.72      0.72       928
#    macro avg       0.72      0.72      0.72       928
# weighted avg       0.72      0.72      0.72       928
#
# LEMMATIZED
# Confusion Matrix for Decision Tree:
# [[373 122]
#  [129 304]]
# Score: 72.95
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.75      0.75       495
#            1       0.71      0.70      0.71       433
#
#    micro avg       0.73      0.73      0.73       928
#    macro avg       0.73      0.73      0.73       928
# weighted avg       0.73      0.73      0.73       928
#
# LANCASTER
# Confusion Matrix for Decision Tree:
# [[360 135]
#  [128 305]]
# Score: 71.66
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.73      0.73       495
#            1       0.69      0.70      0.70       433
#
#    micro avg       0.72      0.72      0.72       928
#    macro avg       0.72      0.72      0.72       928
# weighted avg       0.72      0.72      0.72       928

# %% [markdown]
# # SVC

# %%
# SVC
from sklearn.svm import SVC

# WITH STOPWORDS #################################################################################################################

# initialization
svm = SVC(random_state=101, kernel='linear')
svm.fit(x_train_cleanWithStopwords,y_train)

# predicting
prediction = svm.predict(x_test_cleanWithStopwords)
print("CLEANED WITH STOPWORDS")
print("Confusion Matrix for Support Vector Machines:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_svc_with_stopwords.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# WITHOUT STOPWORDS #################################################################################################################

# initialization
svm = SVC(random_state=101, kernel='linear')
svm.fit(x_train_cleanNoStopwords,y_train)

# predicting
prediction = svm.predict(x_test_cleanNoStopwords)
print("WITHOUT STOPWORDS")
print("Confusion Matrix for Support Vector Machines:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_svc_no_stopwords.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# PORTERSTEMMER #################################################################################################################

# initialization
svm = SVC(random_state=101, kernel='linear')
svm.fit(x_train_porterStemmer,y_train)

# predicting
prediction = svm.predict(x_test_porterStemmer)
print("PORTERSTEMMER")
print("Confusion Matrix for Support Vector Machines:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_svc_porterstemmer.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# SNOWBALLSTEMMER #################################################################################################################

# initialization
svm = SVC(random_state=101, kernel='linear')
svm.fit(x_train_snowballStemmer,y_train)

# predicting
prediction = svm.predict(x_test_snowballStemmer)
print("SNOWBALLSTEMMER")
print("Confusion Matrix for Support Vector Machines:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_svc_snowballstemmer.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# LEMMATIZED #################################################################################################################

# initialization
svm = SVC(random_state=101, kernel='linear')
svm.fit(x_train_lemmatized,y_train)

# predicting
prediction = svm.predict(x_test_lemmatized)
print("LEMMATIZED")
print("Confusion Matrix for Support Vector Machines:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_svc_lemmatized.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# LANCASTER #################################################################################################################

# initialization
svm = SVC(random_state=101, kernel='linear')
svm.fit(x_train_lancaster,y_train)

# predicting
prediction = svm.predict(x_test_lancaster)
print("LANCASTER")
print("Confusion Matrix for Support Vector Machines:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_svc_lancaster.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))
# Out:
# CLEANED WITH STOPWORDS
# Confusion Matrix for Support Vector Machines:
# [[471  24]
#  [ 28 405]]
# Score: 94.4
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.95      0.95       495
#            1       0.94      0.94      0.94       433
#
#    micro avg       0.94      0.94      0.94       928
#    macro avg       0.94      0.94      0.94       928
# weighted avg       0.94      0.94      0.94       928
#
# WITHOUT STOPWORDS
# Confusion Matrix for Support Vector Machines:
# [[463  32]
#  [ 22 411]]
# Score: 94.18
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94       495
#            1       0.93      0.95      0.94       433
#
#    micro avg       0.94      0.94      0.94       928
#    macro avg       0.94      0.94      0.94       928
# weighted avg       0.94      0.94      0.94       928
#
# PORTERSTEMMER
# Confusion Matrix for Support Vector Machines:
# [[460  35]
#  [ 23 410]]
# Score: 93.75
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94       495
#            1       0.92      0.95      0.93       433
#
#    micro avg       0.94      0.94      0.94       928
#    macro avg       0.94      0.94      0.94       928
# weighted avg       0.94      0.94      0.94       928
#
# SNOWBALLSTEMMER
# Confusion Matrix for Support Vector Machines:
# [[463  32]
#  [ 21 412]]
# Score: 94.29
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       495
#            1       0.93      0.95      0.94       433
#
#    micro avg       0.94      0.94      0.94       928
#    macro avg       0.94      0.94      0.94       928
# weighted avg       0.94      0.94      0.94       928
#
# LEMMATIZED
# Confusion Matrix for Support Vector Machines:
# [[464  31]
#  [ 30 403]]
# Score: 93.43
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94       495
#            1       0.93      0.93      0.93       433
#
#    micro avg       0.93      0.93      0.93       928
#    macro avg       0.93      0.93      0.93       928
# weighted avg       0.93      0.93      0.93       928
#
# LANCASTER
# Confusion Matrix for Support Vector Machines:
# [[463  32]
#  [ 24 409]]
# Score: 93.97
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94       495
#            1       0.93      0.94      0.94       433
#
#    micro avg       0.94      0.94      0.94       928
#    macro avg       0.94      0.94      0.94       928
# weighted avg       0.94      0.94      0.94       928

# %% [markdown]
# # Gradient Boosting Classifier

# %%
# Gradient Boosting Classifier
from sklearn.ensemble import GradientBoostingClassifier

# WITH STOPWORDS #################################################################################################################

# initialization
gbi = GradientBoostingClassifier(learning_rate=0.1,max_depth=5,max_features=0.5,random_state=101)
gbi.fit(x_train_cleanWithStopwords,y_train)

# predicting
prediction = gbi.predict(x_test_cleanWithStopwords)
print("WITH STOPWORDS")
print("Confusion Matrix for Gradient Boosting Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_gbi_with_stopwords.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))

# WITHOUT STOPWORDS #################################################################################################################

# initialization
gbi = GradientBoostingClassifier(learning_rate=0.1,max_depth=5,max_features=0.5,random_state=101)
gbi.fit(x_train_cleanNoStopwords,y_train)

# predicting
prediction = gbi.predict(x_test_cleanNoStopwords)
print("WITHOUT STOPWORDS")
print("Confusion Matrix for Gradient Boosting Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_gbi_no_stopwords.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# PORTERSTEMMER #################################################################################################################

# initialization
gbi = GradientBoostingClassifier(learning_rate=0.1,max_depth=5,max_features=0.5,random_state=101)
gbi.fit(x_train_porterStemmer,y_train)

# predicting
prediction = gbi.predict(x_test_porterStemmer)
print("PORTERSTEMMER")
print("Confusion Matrix for Gradient Boosting Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_gbi_porterstemmer.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# SNOWBALLSTEMMER #################################################################################################################

# initialization
gbi = GradientBoostingClassifier(learning_rate=0.1,max_depth=5,max_features=0.5,random_state=101)
gbi.fit(x_train_snowballStemmer,y_train)

# predicting
prediction = gbi.predict(x_test_snowballStemmer)
print("PORTERSTEMMER")
print("Confusion Matrix for Gradient Boosting Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_gbi_snowballstemmer.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# LEMMATIZED #################################################################################################################

# initialization
gbi = GradientBoostingClassifier(learning_rate=0.1,max_depth=5,max_features=0.5,random_state=101)
gbi.fit(x_train_lemmatized,y_train)

# predicting
prediction = gbi.predict(x_test_lemmatized)
print("LEMMATIZED")
print("Confusion Matrix for Gradient Boosting Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_gbi_lemmatized.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))



# LANCASTER #################################################################################################################

# initialization
gbi = GradientBoostingClassifier(learning_rate=0.1,max_depth=5,max_features=0.5,random_state=101)
gbi.fit(x_train_lancaster,y_train)

# predicting
prediction = gbi.predict(x_test_lancaster)
print("LANCASTER")
print("Confusion Matrix for Gradient Boosting Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_gbi_lancaster.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))
# Out:
# WITH STOPWORDS
# Confusion Matrix for Gradient Boosting Classifier:
# [[441  54]
#  [ 59 374]]
# Score: 87.82
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.89      0.89       495
#            1       0.87      0.86      0.87       433
#
#    micro avg       0.88      0.88      0.88       928
#    macro avg       0.88      0.88      0.88       928
# weighted avg       0.88      0.88      0.88       928
#
# WITHOUT STOPWORDS
# Confusion Matrix for Gradient Boosting Classifier:
# [[438  57]
#  [ 68 365]]
# Score: 86.53
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.88      0.88       495
#            1       0.86      0.84      0.85       433
#
#    micro avg       0.87      0.87      0.87       928
#    macro avg       0.87      0.86      0.86       928
# weighted avg       0.87      0.87      0.87       928
#
# PORTERSTEMMER
# Confusion Matrix for Gradient Boosting Classifier:
# [[442  53]
#  [ 67 366]]
# Score: 87.07
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88       495
#            1       0.87      0.85      0.86       433
#
#    micro avg       0.87      0.87      0.87       928
#    macro avg       0.87      0.87      0.87       928
# weighted avg       0.87      0.87      0.87       928
#
# PORTERSTEMMER
# Confusion Matrix for Gradient Boosting Classifier:
# [[442  53]
#  [ 63 370]]
# Score: 87.5
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.89      0.88       495
#            1       0.87      0.85      0.86       433
#
#    micro avg       0.88      0.88      0.88       928
#    macro avg       0.87      0.87      0.87       928
# weighted avg       0.87      0.88      0.87       928
#
# LEMMATIZED
# Confusion Matrix for Gradient Boosting Classifier:
# [[442  53]
#  [ 59 374]]
# Score: 87.93
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.89      0.89       495
#            1       0.88      0.86      0.87       433
#
#    micro avg       0.88      0.88      0.88       928
#    macro avg       0.88      0.88      0.88       928
# weighted avg       0.88      0.88      0.88       928
#
# LANCASTER
# Confusion Matrix for Gradient Boosting Classifier:
# [[438  57]
#  [ 68 365]]
# Score: 86.53
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.88      0.88       495
#            1       0.86      0.84      0.85       433
#
#    micro avg       0.87      0.87      0.87       928
#    macro avg       0.87      0.86      0.86       928
# weighted avg       0.87      0.87      0.87       928

# %%
# K Nearest Neighbour Algorithm
from sklearn.neighbors import KNeighborsClassifier

# WITH STOPWORDS #################################################################################################################

# initialization
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(x_train_cleanWithStopwords,y_train)

# predicting
prediction = knn.predict(x_test_cleanWithStopwords)
print("CLEANED WITH STOPWORDS")
print("Confusion Matrix for K Neighbors Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_knn_with_stopwords.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))

# WITHOUT STOPWORDS #################################################################################################################

# initialization
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(x_train_cleanNoStopwords,y_train)

# predicting
prediction = knn.predict(x_test_cleanNoStopwords)
print("WITHOUT STOPWORDS")
print("Confusion Matrix for K Neighbors Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_knn_no_stopwords.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# PORTERSTEMMER #################################################################################################################

# initialization
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(x_train_porterStemmer,y_train)

# predicting
prediction = knn.predict(x_test_porterStemmer)
print("PORTERSTEMMER")
print("Confusion Matrix for K Neighbors Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_knn_porterstemmer.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# SNOWBALLSTEMMER #################################################################################################################

# initialization
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(x_train_snowballStemmer,y_train)

# predicting
prediction = knn.predict(x_test_snowballStemmer)
print("SNOWBALLSTEMMER")
print("Confusion Matrix for K Neighbors Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_knn_snowballstemmer.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# LEMMATIZED #################################################################################################################

# initialization
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(x_train_lemmatized,y_train)

# predicting
prediction = knn.predict(x_test_lemmatized)
print("LEMMATIZED")
print("Confusion Matrix for K Neighbors Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_knn_lemmatized.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# LANCASTER #################################################################################################################

# initialization
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(x_train_lancaster,y_train)

# predicting
prediction = knn.predict(x_test_lancaster)
print("LANCASTER")
print("Confusion Matrix for K Neighbors Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_knn_lancaster.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))
# Out:
# CLEANED WITH STOPWORDS
# Confusion Matrix for K Neighbors Classifier:
# [[387 108]
#  [123 310]]
# Score: 75.11
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.76      0.78      0.77       495
#            1       0.74      0.72      0.73       433
#
#    micro avg       0.75      0.75      0.75       928
#    macro avg       0.75      0.75      0.75       928
# weighted avg       0.75      0.75      0.75       928
#
# WITHOUT STOPWORDS
# Confusion Matrix for K Neighbors Classifier:
# [[384 111]
#  [124 309]]
# Score: 74.68
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.76      0.78      0.77       495
#            1       0.74      0.71      0.72       433
#
#    micro avg       0.75      0.75      0.75       928
#    macro avg       0.75      0.74      0.75       928
# weighted avg       0.75      0.75      0.75       928
#
# PORTERSTEMMER
# Confusion Matrix for K Neighbors Classifier:
# [[384 111]
#  [143 290]]
# Score: 72.63
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.73      0.78      0.75       495
#            1       0.72      0.67      0.70       433
#
#    micro avg       0.73      0.73      0.73       928
#    macro avg       0.73      0.72      0.72       928
# weighted avg       0.73      0.73      0.73       928
#
# SNOWBALLSTEMMER
# Confusion Matrix for K Neighbors Classifier:
# [[386 109]
#  [142 291]]
# Score: 72.95
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.73      0.78      0.75       495
#            1       0.73      0.67      0.70       433
#
#    micro avg       0.73      0.73      0.73       928
#    macro avg       0.73      0.73      0.73       928
# weighted avg       0.73      0.73      0.73       928
#
# LEMMATIZED
# Confusion Matrix for K Neighbors Classifier:
# [[387 108]
#  [129 304]]
# Score: 74.46
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.78      0.77       495
#            1       0.74      0.70      0.72       433
#
#    micro avg       0.74      0.74      0.74       928
#    macro avg       0.74      0.74      0.74       928
# weighted avg       0.74      0.74      0.74       928
#
# LANCASTER
# Confusion Matrix for K Neighbors Classifier:
# [[382 113]
#  [129 304]]
# Score: 73.92
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.77      0.76       495
#            1       0.73      0.70      0.72       433
#
#    micro avg       0.74      0.74      0.74       928
#    macro avg       0.74      0.74      0.74       928
# weighted avg       0.74      0.74      0.74       928

# %% [markdown]
# # Multilayer Perceptron Classifier

# %%
# Mulilayer Perceptron Classifier
from sklearn.neural_network import MLPClassifier

# WITH STOPWORDS #################################################################################################################

# initialization
mlp = MLPClassifier()
mlp.fit(x_train_cleanWithStopwords,y_train)

# predicting
prediction = mlp.predict(x_test_cleanWithStopwords)
print("WITH STOPWORDS")
print("Confusion Matrix for Multilayer Perceptron Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_mlp_with_stopwords.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))

# WITHOUT STOPWORDS #################################################################################################################

# initialization
mlp = MLPClassifier()
mlp.fit(x_train_cleanNoStopwords,y_train)

# predicting
prediction = mlp.predict(x_test_cleanNoStopwords)
print("WITHOUT STOPWORDS")
print("Confusion Matrix for Multilayer Perceptron Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_mlp_no_stopwords.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# PORTERSTEMMER #################################################################################################################

# initialization
mlp = MLPClassifier()
mlp.fit(x_train_porterStemmer,y_train)

# predicting
prediction = mlp.predict(x_test_porterStemmer)
print("PORTERSTEMMER")
print("Confusion Matrix for Multilayer Perceptron Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_mlp_porterstemmer.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# SNOWBALLSTEMMER #################################################################################################################

# initialization
mlp = MLPClassifier()
mlp.fit(x_train_snowballStemmer,y_train)

# predicting
prediction = mlp.predict(x_test_snowballStemmer)
print("SNOWBALLSTEMMER")
print("Confusion Matrix for Multilayer Perceptron Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_mlp_snowballstemmer.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# LEMMATIZED #################################################################################################################

# initialization
mlp = MLPClassifier()
mlp.fit(x_train_lemmatized,y_train)

# predicting
prediction = mlp.predict(x_test_lemmatized)
print("LEMMATIZED")
print("Confusion Matrix for Multilayer Perceptron Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_mlp_lemmatized.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# LANCASTER #################################################################################################################

# initialization
mlp = MLPClassifier()
mlp.fit(x_train_lancaster,y_train)

# predicting
prediction = mlp.predict(x_test_lancaster)
print("LANCASTER")
print("Confusion Matrix for Multilayer Perceptron Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_mlp_lancaster.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))
# Out:
# WITH STOPWORDS
# Confusion Matrix for Multilayer Perceptron Classifier:
# [[459  36]
#  [ 19 414]]
# Score: 94.07
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94       495
#            1       0.92      0.96      0.94       433
#
#    micro avg       0.94      0.94      0.94       928
#    macro avg       0.94      0.94      0.94       928
# weighted avg       0.94      0.94      0.94       928
#
# WITHOUT STOPWORDS
# Confusion Matrix for Multilayer Perceptron Classifier:
# [[459  36]
#  [ 26 407]]
# Score: 93.32
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94       495
#            1       0.92      0.94      0.93       433
#
#    micro avg       0.93      0.93      0.93       928
#    macro avg       0.93      0.93      0.93       928
# weighted avg       0.93      0.93      0.93       928
#
# PORTERSTEMMER
# Confusion Matrix for Multilayer Perceptron Classifier:
# [[456  39]
#  [ 28 405]]
# Score: 92.78
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93       495
#            1       0.91      0.94      0.92       433
#
#    micro avg       0.93      0.93      0.93       928
#    macro avg       0.93      0.93      0.93       928
# weighted avg       0.93      0.93      0.93       928
#
# SNOWBALLSTEMMER
# Confusion Matrix for Multilayer Perceptron Classifier:
# [[455  40]
#  [ 23 410]]
# Score: 93.21
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94       495
#            1       0.91      0.95      0.93       433
#
#    micro avg       0.93      0.93      0.93       928
#    macro avg       0.93      0.93      0.93       928
# weighted avg       0.93      0.93      0.93       928
#
# LEMMATIZED
# Confusion Matrix for Multilayer Perceptron Classifier:
# [[457  38]
#  [ 28 405]]
# Score: 92.89
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93       495
#            1       0.91      0.94      0.92       433
#
#    micro avg       0.93      0.93      0.93       928
#    macro avg       0.93      0.93      0.93       928
# weighted avg       0.93      0.93      0.93       928
#
# LANCASTER
# Confusion Matrix for Multilayer Perceptron Classifier:
# [[449  46]
#  [ 27 406]]
# Score: 92.13
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.91      0.92       495
#            1       0.90      0.94      0.92       433
#
#    micro avg       0.92      0.92      0.92       928
#    macro avg       0.92      0.92      0.92       928
# weighted avg       0.92      0.92      0.92       928

# %% [markdown]
# # Logistic Regression

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression

# WITH STOPWORDS #################################################################################################################

# initialization
lrg = LogisticRegression(C=1e5, solver='saga', multi_class='multinomial', random_state = 101)
lrg.fit(x_train_cleanWithStopwords,y_train)

# predicting
prediction = lrg.predict(x_test_cleanWithStopwords)
print("WITH STOPWORDS")
print("CLEANED WITH STOPWORDS")
print("Confusion Matrix for Logistic Regression:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_lrg_with_stopwords.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))

# WITHOUT STOPWORDS #################################################################################################################

# initialization
lrg = LogisticRegression(C=1e5, solver='saga', multi_class='multinomial', random_state = 101)
lrg.fit(x_train_cleanNoStopwords,y_train)

# predicting
prediction = lrg.predict(x_test_cleanNoStopwords)
print("WITHOUT STOPWORDS")
print("CLEANED WITH STOPWORDS")
print("Confusion Matrix for Logistic Regression:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_lrg_no_stopwords.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# PORTERSTEMMER #################################################################################################################

# initialization
lrg = LogisticRegression(C=1e5, solver='saga', multi_class='multinomial', random_state = 101)
lrg.fit(x_train_porterStemmer,y_train)

# predicting
prediction = lrg.predict(x_test_porterStemmer)
print("PORTERSTEMMER")
print("CLEANED WITH STOPWORDS")
print("Confusion Matrix for Logistic Regression:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_lrg_porterstemmer.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# SNOWBALLSTEMMER #################################################################################################################

# initialization
lrg = LogisticRegression(C=1e5, solver='saga', multi_class='multinomial', random_state = 101)
lrg.fit(x_train_snowballStemmer,y_train)

# predicting
prediction = lrg.predict(x_test_snowballStemmer)
print("SNOWBALLSTEMMER")
print("CLEANED WITH STOPWORDS")
print("Confusion Matrix for Logistic Regression:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_lrg_snowballstemmer.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# LEMMATIZED #################################################################################################################

# initialization
lrg = LogisticRegression(C=1e5, solver='saga', multi_class='multinomial', random_state = 101)
lrg.fit(x_train_lemmatized,y_train)

# predicting
prediction = lrg.predict(x_test_lemmatized)
print("LEMMATIZED")
print("CLEANED WITH STOPWORDS")
print("Confusion Matrix for Logistic Regression:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_lrg_lemmatized.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))

# LANCASTER #################################################################################################################

# initialization
lrg = LogisticRegression(C=1e5, solver='saga', multi_class='multinomial', random_state = 101)
lrg.fit(x_train_lancaster,y_train)

# predicting
prediction = lrg.predict(x_test_lancaster)
print("LANCASTER")
print("CLEANED WITH STOPWORDS")
print("Confusion Matrix for Logistic Regression:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("tf_trigram_lrg_lancaster.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# WITH STOPWORDS
# CLEANED WITH STOPWORDS
# Confusion Matrix for Logistic Regression:
# [[472  23]
#  [ 25 408]]
# Score: 94.83
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       495
#            1       0.95      0.94      0.94       433
#
#    micro avg       0.95      0.95      0.95       928
#    macro avg       0.95      0.95      0.95       928
# weighted avg       0.95      0.95      0.95       928
#
# WITHOUT STOPWORDS
# CLEANED WITH STOPWORDS
# Confusion Matrix for Logistic Regression:
# [[464  31]
#  [ 23 410]]
# Score: 94.18
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95       495
#            1       0.93      0.95      0.94       433
#
#    micro avg       0.94      0.94      0.94       928
#    macro avg       0.94      0.94      0.94       928
# weighted avg       0.94      0.94      0.94       928
#
# PORTERSTEMMER
# CLEANED WITH STOPWORDS
# Confusion Matrix for Logistic Regression:
# [[457  38]
#  [ 18 415]]
# Score: 93.97
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94       495
#            1       0.92      0.96      0.94       433
#
#    micro avg       0.94      0.94      0.94       928
#    macro avg       0.94      0.94      0.94       928
# weighted avg       0.94      0.94      0.94       928
#
# SNOWBALLSTEMMER
# CLEANED WITH STOPWORDS
# Confusion Matrix for Logistic Regression:
# [[463  32]
#  [ 19 414]]
# Score: 94.5
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       495
#            1       0.93      0.96      0.94       433
#
#    micro avg       0.95      0.95      0.95       928
#    macro avg       0.94      0.95      0.94       928
# weighted avg       0.95      0.95      0.95       928
#
# LEMMATIZED
# CLEANED WITH STOPWORDS
# Confusion Matrix for Logistic Regression:
# [[462  33]
#  [ 23 410]]
# Score: 93.97
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94       495
#            1       0.93      0.95      0.94       433
#
#    micro avg       0.94      0.94      0.94       928
#    macro avg       0.94      0.94      0.94       928
# weighted avg       0.94      0.94      0.94       928
#
# LANCASTER
# CLEANED WITH STOPWORDS
# Confusion Matrix for Logistic Regression:
# [[459  36]
#  [ 26 407]]
# Score: 93.32
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94       495
#            1       0.92      0.94      0.93       433
#
#    micro avg       0.93      0.93      0.93       928
#    macro avg       0.93      0.93      0.93       928
# weighted avg       0.93      0.93      0.93       928

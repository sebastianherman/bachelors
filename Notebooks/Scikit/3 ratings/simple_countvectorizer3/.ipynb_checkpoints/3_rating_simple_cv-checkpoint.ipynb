# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, roc_curve

from sklearn import metrics

import contractions

import scikitplot as skplt
import matplotlib.pyplot as plt

# %%
yelp_data_5k = pd.read_csv(r"C:\Users\sebas\Documents\School\bachelor-final\Dataset\PROCESSED_RESTAURANT_REVIEWS_5k.csv")

# %%
yelp_data_5k.head()
# Out:
#    Unnamed: 0                                      reviewContent  usefulCount  \
# 0           0  "'Check, Please." The bartender was unable to ...           18
# 1           1  "2 stars for disappointing food, one star for ...           14
# 2           2  "A Divine Dialogue" God: "Britton. Times up. T...           14
# 3           3  "A Place To Go When You Have Time" It was a mi...           13
# 4           4  "A Thaiphoon of Flavor" My First: I never enli...           27
#
#    coolCount  funnyCount  rating            restaurantID  \
# 0         11          25       1  VZHyAmdFDreQqL0BT-zdoA
# 1         10           7       3  tFcmrGLZNEymSnijoTPmqw
# 2         16          23       5  INvIaBFnAvGxzTXFWHzGvA
# 3         10          10       5  FySId5SjNhkrtPA5qktdxg
# 4         22          28       5  RgeMUiZncTs-VSHQLm0wNg
#
#                             reviewCleanWithStopwords  \
# 0  check please the bartender was unable to recom...
# 1  stars for disappointing food one star for grea...
# 2  divine dialogue god britton times up the world...
# 3  place to go when you have time it was misty br...
# 4  thaiphoon of flavor my first never enlisted in...
#
#                               reviewCleanNoStopwords  \
# 0  check please bartender unable recommend beer t...
# 1  stars disappointing food one star great servic...
# 2  divine dialogue god britton times world going ...
# 3  place go time misty breezy summer night friend...
# 4  thaiphoon flavor first never enlisted air forc...
#
#                             reviewCleanPorterStemmer  \
# 0  check pleas bartend unabl recommend beer tap t...
# 1  star disappoint food one star great servic rea...
# 2  divin dialogu god britton time world go end to...
# 3  place go time misti breezi summer night friend...
# 4  thaiphoon flavor first never enlist air forc a...
#
#                           reviewCleanSnowballStemmer  \
# 0  check pleas bartend unabl recommend beer tap t...
# 1  star disappoint food one star great servic rea...
# 2  divin dialogu god britton time world go end to...
# 3  place go time misti breezi summer night friend...
# 4  thaiphoon flavor first never enlist air forc a...
#
#                                reviewCleanLemmatized  \
# 0  check please bartender unable recommend beer t...
# 1  star disappoint food one star great service re...
# 2  divine dialogue god britton time world go end ...
# 3  place go time misty breezy summer night friend...
# 4  thaiphoon flavor first never enlist air force ...
#
#                                 reviewCleanLancaster
# 0  check pleas bartend un recommend beer tap tri ...
# 1  star disappoint food on star gre serv read iai...
# 2  divin dialog god britton tim world going end t...
# 3  plac go tim misty breezy sum night friend jere...
# 4  thaiphoon flav first nev enl air forc allow jo...

# %%
yelp_data_5k.rating.value_counts()
# Out:
# 2    1250
# 5    1179
# 1    1159
# 3    1130
# 4    1051
# Name: rating, dtype: int64

# %%
yelp_data_5k.isnull().values.any()
# Out:
# False

# %% [markdown]
# # Remove data from table with rating = 2 or 4

# %%
# Get names of indexes for which column rating has value 2
indexNamesRating2 = yelp_data_5k[ yelp_data_5k['rating'] == 2 ].index
 
# Delete these row indexes from dataFrame
yelp_data_5k.drop(indexNamesRating2, inplace=True)

# Get names of indexes for which column rating has value 4
indexNamesRating4 = yelp_data_5k[ yelp_data_5k['rating'] == 4 ].index
 
# Delete these row indexes from dataFrame
yelp_data_5k.drop(indexNamesRating4, inplace=True)

# %%
yelp_data_5k.rating.value_counts()
# Out:
# 5    1179
# 1    1159
# 3    1130
# Name: rating, dtype: int64

# %% [markdown]
# # Allocating each text with its specific cleaning method to a variable

# %%
x_cleanWithStopwords = yelp_data_5k["reviewCleanWithStopwords"]
x_cleanNoStopwords = yelp_data_5k["reviewCleanNoStopwords"]
x_porterStemmer = yelp_data_5k["reviewCleanPorterStemmer"]
x_snowballStemmer = yelp_data_5k["reviewCleanSnowballStemmer"]
x_lemmatized = yelp_data_5k["reviewCleanLemmatized"]
x_lancaster = yelp_data_5k["reviewCleanLancaster"]

# %% [markdown]
# # Vectorisation

# %%
cv = CountVectorizer(min_df=5).fit(x_cleanWithStopwords)
x_cleanWithStopwords = cv.transform(x_cleanWithStopwords)

cv = CountVectorizer(min_df=5).fit(x_cleanNoStopwords)
x_cleanNoStopwords = cv.transform(x_cleanNoStopwords)

cv = CountVectorizer(min_df=5).fit(x_porterStemmer)
x_porterStemmer = cv.transform(x_porterStemmer)

cv = CountVectorizer(min_df=5).fit(x_snowballStemmer)
x_snowballStemmer = cv.transform(x_snowballStemmer)

cv = CountVectorizer(min_df=5).fit(x_lemmatized)
x_lemmatized = cv.transform(x_lemmatized)

cv = CountVectorizer(min_df=5).fit(x_lancaster)
x_lancaster = cv.transform(x_lancaster)

# %%
y = yelp_data_5k["rating"]

# %% [markdown]
# # Splitting the data for training and testing

# %%
x_train_cleanWithStopwords, x_test_cleanWithStopwords, y_train, y_test = train_test_split(x_cleanWithStopwords, y, test_size=0.2, random_state=50)

x_train_cleanNoStopwords, x_test_cleanNoStopwords, y_train, y_test = train_test_split(x_cleanNoStopwords, y, test_size=0.2, random_state=50)

x_train_porterStemmer, x_test_porterStemmer, y_train, y_test = train_test_split(x_porterStemmer, y, test_size=0.2, random_state=50)

x_train_snowballStemmer, x_test_snowballStemmer, y_train, y_test = train_test_split(x_snowballStemmer, y, test_size=0.2, random_state=50)

x_train_lemmatized, x_test_lemmatized, y_train, y_test = train_test_split(x_lemmatized, y, test_size=0.2, random_state=50)

x_train_lancaster, x_test_lancaster, y_train, y_test = train_test_split(x_lancaster, y, test_size=0.2, random_state=50)

# %% [markdown]
# # Models
# ## Multinomial Naive Bayes

# %%
# Multinomial Naive Bayes
from sklearn.naive_bayes import MultinomialNB

# WITH STOPWORDS #################################################################################################################

# initialization
mnb = MultinomialNB()
mnb.fit(x_train_cleanWithStopwords, y_train)

# predicting
prediction = mnb.predict(x_test_cleanWithStopwords)

# generating and printing confusion matrix
print("WITH STOPWORDS")
print("Confusion Matrix for Multinomial Naive Bayes:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_mnb_with_stopwords_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# WITHOUT STOPWORDS #################################################################################################################


# initialization
mnb = MultinomialNB()
mnb.fit(x_train_cleanNoStopwords, y_train)

# predicting
prediction = mnb.predict(x_test_cleanNoStopwords)

# generating and printing confusion matrix
print("WITHOUT STOPWORDS")
print("Confusion Matrix for Multinomial Naive Bayes:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_mnb_no_stopwords_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# PORTERSTEMMER #################################################################################################################


# initialization
mnb = MultinomialNB()
mnb.fit(x_train_porterStemmer, y_train)

# predicting
prediction = mnb.predict(x_test_porterStemmer)

# generating and printing confusion matrix
print("PORTERSTEMMER")
print("Confusion Matrix for Multinomial Naive Bayes:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_mnb_porterstemmer_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# SNOWBALLSTEMMER #################################################################################################################


# initialization
mnb = MultinomialNB()
mnb.fit(x_train_snowballStemmer, y_train)

# predicting
prediction = mnb.predict(x_test_snowballStemmer)

# generating and printing confusion matrix
print("SNOWBALLSTEMMER")
print("Confusion Matrix for Multinomial Naive Bayes:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_mnb_snowballstemmer_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# LEMMATIZED #################################################################################################################


# initialization
mnb = MultinomialNB()
mnb.fit(x_train_lemmatized, y_train)

# predicting
prediction = mnb.predict(x_test_lemmatized)

# generating and printing confusion matrix
print("LEMMATIZED")
print("Confusion Matrix for Multinomial Naive Bayes:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_mnb_lemmatized_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# LANCASTER #################################################################################################################


# initialization
mnb = MultinomialNB()
mnb.fit(x_train_lancaster, y_train)

# predicting
prediction = mnb.predict(x_test_lancaster)

# generating and printing confusion matrix
print("LANCASTER")
print("Confusion Matrix for Multinomial Naive Bayes:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_mnb_lancaster_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))
# Out:
# WITH STOPWORDS
# Confusion Matrix for Multinomial Naive Bayes:
# [[207  38   3]
#  [ 41 147  31]
#  [ 21  46 160]]
# Score: 74.06
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.77      0.83      0.80       248
#            3       0.64      0.67      0.65       219
#            5       0.82      0.70      0.76       227
#
#    micro avg       0.74      0.74      0.74       694
#    macro avg       0.74      0.74      0.74       694
# weighted avg       0.75      0.74      0.74       694
#
# WITHOUT STOPWORDS
# Confusion Matrix for Multinomial Naive Bayes:
# [[209  35   4]
#  [ 39 148  32]
#  [ 21  49 157]]
# Score: 74.06
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.78      0.84      0.81       248
#            3       0.64      0.68      0.66       219
#            5       0.81      0.69      0.75       227
#
#    micro avg       0.74      0.74      0.74       694
#    macro avg       0.74      0.74      0.74       694
# weighted avg       0.75      0.74      0.74       694
#
# PORTERSTEMMER
# Confusion Matrix for Multinomial Naive Bayes:
# [[205  38   5]
#  [ 39 150  30]
#  [ 21  49 157]]
# Score: 73.78
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.77      0.83      0.80       248
#            3       0.63      0.68      0.66       219
#            5       0.82      0.69      0.75       227
#
#    micro avg       0.74      0.74      0.74       694
#    macro avg       0.74      0.73      0.74       694
# weighted avg       0.74      0.74      0.74       694
#
# SNOWBALLSTEMMER
# Confusion Matrix for Multinomial Naive Bayes:
# [[206  36   6]
#  [ 40 149  30]
#  [ 22  48 157]]
# Score: 73.78
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.77      0.83      0.80       248
#            3       0.64      0.68      0.66       219
#            5       0.81      0.69      0.75       227
#
#    micro avg       0.74      0.74      0.74       694
#    macro avg       0.74      0.73      0.74       694
# weighted avg       0.74      0.74      0.74       694
#
# LEMMATIZED
# Confusion Matrix for Multinomial Naive Bayes:
# [[204  40   4]
#  [ 37 148  34]
#  [ 23  46 158]]
# Score: 73.49
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.77      0.82      0.80       248
#            3       0.63      0.68      0.65       219
#            5       0.81      0.70      0.75       227
#
#    micro avg       0.73      0.73      0.73       694
#    macro avg       0.74      0.73      0.73       694
# weighted avg       0.74      0.73      0.74       694
#
# LANCASTER
# Confusion Matrix for Multinomial Naive Bayes:
# [[205  37   6]
#  [ 36 151  32]
#  [ 23  44 160]]
# Score: 74.35
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.78      0.83      0.80       248
#            3       0.65      0.69      0.67       219
#            5       0.81      0.70      0.75       227
#
#    micro avg       0.74      0.74      0.74       694
#    macro avg       0.75      0.74      0.74       694
# weighted avg       0.75      0.74      0.74       694

# %% [markdown]
# ## Random Forrest

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier

# WITH STOPWORDS #################################################################################################################

# initialization
rmf = RandomForestClassifier(n_estimators=200)
rmf.fit(x_train_cleanWithStopwords,y_train)

# predicting
prediction = rmf.predict(x_test_cleanWithStopwords)

# generating and printing confusion matrix
print("CLEANED WITH STOPWORDS")
print("Confusion Matrix for Random Forest Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_rmf_with_stopwords_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# WITHOUT STOPWORDS #################################################################################################################


# initialization
rmf = RandomForestClassifier(n_estimators=200)
rmf.fit(x_train_cleanNoStopwords,y_train)

# predicting
prediction = rmf.predict(x_test_cleanNoStopwords)

# generating and printing confusion matrix
print("WITHOUT STOPWORDS")
print("Confusion Matrix for Random Forest Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_rmf_no_stopwords_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# PORTERSTEMMER #################################################################################################################


# initialization
rmf = RandomForestClassifier(n_estimators=200)
rmf.fit(x_train_porterStemmer,y_train)

# predicting
prediction = rmf.predict(x_test_porterStemmer)

# generating and printing confusion matrix
print("PORTERSTEMMER")
print("Confusion Matrix for Random Forest Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_rmf_porterstemmer_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# SNOWBALLSTEMMER #################################################################################################################


# initialization
rmf = RandomForestClassifier(n_estimators=200)
rmf.fit(x_train_snowballStemmer,y_train)

# predicting
prediction = rmf.predict(x_test_snowballStemmer)

# generating and printing confusion matrix
print("SNOWBALLSTEMMER")
print("Confusion Matrix for Random Forest Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_rmf_snowballstemmer_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# LEMMATIZED #################################################################################################################


# initialization
rmf = RandomForestClassifier(n_estimators=200)
rmf.fit(x_train_lemmatized,y_train)

# predicting
prediction = rmf.predict(x_test_lemmatized)

# generating and printing confusion matrix
print("LEMMATIZED")
print("Confusion Matrix for Random Forest Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_rmf_lemmatized_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# LANCASTER #################################################################################################################


# initialization
rmf = RandomForestClassifier(n_estimators=200)
rmf.fit(x_train_lancaster,y_train)

# predicting
prediction = rmf.predict(x_test_lancaster)

# generating and printing confusion matrix
print("LANCASTER")
print("Confusion Matrix for Random Forest Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_rmf_lancaster_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))
# Out:
# CLEANED WITH STOPWORDS
# Confusion Matrix for Random Forest Classifier:
# [[220  21   7]
#  [ 41 137  41]
#  [ 25  41 161]]
# Score: 74.64
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.77      0.89      0.82       248
#            3       0.69      0.63      0.66       219
#            5       0.77      0.71      0.74       227
#
#    micro avg       0.75      0.75      0.75       694
#    macro avg       0.74      0.74      0.74       694
# weighted avg       0.74      0.75      0.74       694
#
# WITHOUT STOPWORDS
# Confusion Matrix for Random Forest Classifier:
# [[218  20  10]
#  [ 41 139  39]
#  [ 18  31 178]]
# Score: 77.09
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.79      0.88      0.83       248
#            3       0.73      0.63      0.68       219
#            5       0.78      0.78      0.78       227
#
#    micro avg       0.77      0.77      0.77       694
#    macro avg       0.77      0.77      0.76       694
# weighted avg       0.77      0.77      0.77       694
#
# PORTERSTEMMER
# Confusion Matrix for Random Forest Classifier:
# [[220  20   8]
#  [ 39 143  37]
#  [ 20  32 175]]
# Score: 77.52
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.79      0.89      0.83       248
#            3       0.73      0.65      0.69       219
#            5       0.80      0.77      0.78       227
#
#    micro avg       0.78      0.78      0.78       694
#    macro avg       0.77      0.77      0.77       694
# weighted avg       0.77      0.78      0.77       694
#
# SNOWBALLSTEMMER
# Confusion Matrix for Random Forest Classifier:
# [[216  22  10]
#  [ 38 133  48]
#  [ 18  32 177]]
# Score: 75.79
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.79      0.87      0.83       248
#            3       0.71      0.61      0.66       219
#            5       0.75      0.78      0.77       227
#
#    micro avg       0.76      0.76      0.76       694
#    macro avg       0.75      0.75      0.75       694
# weighted avg       0.75      0.76      0.75       694
#
# LEMMATIZED
# Confusion Matrix for Random Forest Classifier:
# [[216  23   9]
#  [ 35 136  48]
#  [ 22  31 174]]
# Score: 75.79
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.79      0.87      0.83       248
#            3       0.72      0.62      0.67       219
#            5       0.75      0.77      0.76       227
#
#    micro avg       0.76      0.76      0.76       694
#    macro avg       0.75      0.75      0.75       694
# weighted avg       0.75      0.76      0.75       694
#
# LANCASTER
# Confusion Matrix for Random Forest Classifier:
# [[214  24  10]
#  [ 41 133  45]
#  [ 20  34 173]]
# Score: 74.93
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.78      0.86      0.82       248
#            3       0.70      0.61      0.65       219
#            5       0.76      0.76      0.76       227
#
#    micro avg       0.75      0.75      0.75       694
#    macro avg       0.74      0.74      0.74       694
# weighted avg       0.75      0.75      0.75       694

# %% [markdown]
# ## Decision Tree

# %%
# Decision tree
from sklearn.tree import DecisionTreeClassifier

# WITH STOPWORDS #################################################################################################################

# initialization
dt = DecisionTreeClassifier()
dt.fit(x_train_cleanWithStopwords,y_train)

# predicting
prediction = dt.predict(x_test_cleanWithStopwords)
print("WITH STOPWORDS")
print("Confusion Matrix for Decision Tree:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_dt_with_stopwords_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# WITHOUT STOPWORDS #################################################################################################################

# initialization
dt = DecisionTreeClassifier()
dt.fit(x_train_cleanNoStopwords,y_train)

# predicting
prediction = dt.predict(x_test_cleanNoStopwords)
print("WITHOUT STOPWORDS")
print("Confusion Matrix for Decision Tree:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_dt_no_stopwords_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# PORTERSTEMMER #################################################################################################################

# initialization
dt = DecisionTreeClassifier()
dt.fit(x_train_porterStemmer,y_train)

# predicting
prediction = dt.predict(x_test_porterStemmer)
print("PORTERSTEMMER")
print("Confusion Matrix for Decision Tree:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_dt_porterstemmer_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# SNOWBALLSTEMMER #################################################################################################################

# initialization
dt = DecisionTreeClassifier()
dt.fit(x_train_snowballStemmer,y_train)

# predicting
prediction = dt.predict(x_test_snowballStemmer)
print("SNOWBALLSTEMMER")
print("Confusion Matrix for Decision Tree:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_dt_snowballstemmer_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# LEMMATIZED #################################################################################################################

# initialization
dt = DecisionTreeClassifier()
dt.fit(x_train_lemmatized,y_train)

# predicting
prediction = dt.predict(x_test_lemmatized)
print("LEMMATIZED")
print("Confusion Matrix for Decision Tree:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_dt_lemmatized_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# LANCASTER #################################################################################################################

# initialization
dt = DecisionTreeClassifier()
dt.fit(x_train_lancaster,y_train)

# predicting
prediction = dt.predict(x_test_lancaster)
print("LANCASTER")
print("Confusion Matrix for Decision Tree:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_dt_lancaster_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))
# Out:
# WITH STOPWORDS
# Confusion Matrix for Decision Tree:
# [[145  63  40]
#  [ 52 112  55]
#  [ 44  62 121]]
# Score: 54.47
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.60      0.58      0.59       248
#            3       0.47      0.51      0.49       219
#            5       0.56      0.53      0.55       227
#
#    micro avg       0.54      0.54      0.54       694
#    macro avg       0.54      0.54      0.54       694
# weighted avg       0.55      0.54      0.55       694
#
# WITHOUT STOPWORDS
# Confusion Matrix for Decision Tree:
# [[163  50  35]
#  [ 42 114  63]
#  [ 37  54 136]]
# Score: 59.51
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.67      0.66      0.67       248
#            3       0.52      0.52      0.52       219
#            5       0.58      0.60      0.59       227
#
#    micro avg       0.60      0.60      0.60       694
#    macro avg       0.59      0.59      0.59       694
# weighted avg       0.60      0.60      0.60       694
#
# PORTERSTEMMER
# Confusion Matrix for Decision Tree:
# [[142  72  34]
#  [ 48 123  48]
#  [ 32  62 133]]
# Score: 57.35
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.64      0.57      0.60       248
#            3       0.48      0.56      0.52       219
#            5       0.62      0.59      0.60       227
#
#    micro avg       0.57      0.57      0.57       694
#    macro avg       0.58      0.57      0.57       694
# weighted avg       0.58      0.57      0.58       694
#
# SNOWBALLSTEMMER
# Confusion Matrix for Decision Tree:
# [[141  64  43]
#  [ 47 121  51]
#  [ 35  54 138]]
# Score: 57.64
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.63      0.57      0.60       248
#            3       0.51      0.55      0.53       219
#            5       0.59      0.61      0.60       227
#
#    micro avg       0.58      0.58      0.58       694
#    macro avg       0.58      0.58      0.58       694
# weighted avg       0.58      0.58      0.58       694
#
# LEMMATIZED
# Confusion Matrix for Decision Tree:
# [[147  56  45]
#  [ 51 111  57]
#  [ 30  53 144]]
# Score: 57.93
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.64      0.59      0.62       248
#            3       0.50      0.51      0.51       219
#            5       0.59      0.63      0.61       227
#
#    micro avg       0.58      0.58      0.58       694
#    macro avg       0.58      0.58      0.58       694
# weighted avg       0.58      0.58      0.58       694
#
# LANCASTER
# Confusion Matrix for Decision Tree:
# [[157  46  45]
#  [ 52 118  49]
#  [ 42  57 128]]
# Score: 58.07
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.63      0.63      0.63       248
#            3       0.53      0.54      0.54       219
#            5       0.58      0.56      0.57       227
#
#    micro avg       0.58      0.58      0.58       694
#    macro avg       0.58      0.58      0.58       694
# weighted avg       0.58      0.58      0.58       694

# %% [markdown]
# # SVC

# %%
# SVC
from sklearn.svm import SVC

# WITH STOPWORDS #################################################################################################################

# initialization
svm = SVC(random_state=101, kernel='linear')
svm.fit(x_train_cleanWithStopwords,y_train)

# predicting
prediction = svm.predict(x_test_cleanWithStopwords)
print("CLEANED WITH STOPWORDS")
print("Confusion Matrix for Support Vector Machines:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_svc_with_stopwords_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# WITHOUT STOPWORDS #################################################################################################################

# initialization
svm = SVC(random_state=101, kernel='linear')
svm.fit(x_train_cleanNoStopwords,y_train)

# predicting
prediction = svm.predict(x_test_cleanNoStopwords)
print("WITHOUT STOPWORDS")
print("Confusion Matrix for Support Vector Machines:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_svc_no_stopwords_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# PORTERSTEMMER #################################################################################################################

# initialization
svm = SVC(random_state=101, kernel='linear')
svm.fit(x_train_porterStemmer,y_train)

# predicting
prediction = svm.predict(x_test_porterStemmer)
print("PORTERSTEMMER")
print("Confusion Matrix for Support Vector Machines:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_svc_porterstemmer_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# SNOWBALLSTEMMER #################################################################################################################

# initialization
svm = SVC(random_state=101, kernel='linear')
svm.fit(x_train_snowballStemmer,y_train)

# predicting
prediction = svm.predict(x_test_snowballStemmer)
print("SNOWBALLSTEMMER")
print("Confusion Matrix for Support Vector Machines:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_svc_snowballstemmer_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# LEMMATIZED #################################################################################################################

# initialization
svm = SVC(random_state=101, kernel='linear')
svm.fit(x_train_lemmatized,y_train)

# predicting
prediction = svm.predict(x_test_lemmatized)
print("LEMMATIZED")
print("Confusion Matrix for Support Vector Machines:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_svc_lemmatized_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# LANCASTER #################################################################################################################

# initialization
svm = SVC(random_state=101, kernel='linear')
svm.fit(x_train_lancaster,y_train)

# predicting
prediction = svm.predict(x_test_lancaster)
print("LANCASTER")
print("Confusion Matrix for Support Vector Machines:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_svc_lancaster_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))
# Out:
# CLEANED WITH STOPWORDS
# Confusion Matrix for Support Vector Machines:
# [[215  26   7]
#  [ 31 149  39]
#  [ 15  37 175]]
# Score: 77.67
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.82      0.87      0.84       248
#            3       0.70      0.68      0.69       219
#            5       0.79      0.77      0.78       227
#
#    micro avg       0.78      0.78      0.78       694
#    macro avg       0.77      0.77      0.77       694
# weighted avg       0.78      0.78      0.78       694
#
# WITHOUT STOPWORDS
# Confusion Matrix for Support Vector Machines:
# [[215  29   4]
#  [ 39 144  36]
#  [ 15  49 163]]
# Score: 75.22
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.80      0.87      0.83       248
#            3       0.65      0.66      0.65       219
#            5       0.80      0.72      0.76       227
#
#    micro avg       0.75      0.75      0.75       694
#    macro avg       0.75      0.75      0.75       694
# weighted avg       0.75      0.75      0.75       694
#
# PORTERSTEMMER
# Confusion Matrix for Support Vector Machines:
# [[209  32   7]
#  [ 40 152  27]
#  [ 14  42 171]]
# Score: 76.66
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.79      0.84      0.82       248
#            3       0.67      0.69      0.68       219
#            5       0.83      0.75      0.79       227
#
#    micro avg       0.77      0.77      0.77       694
#    macro avg       0.77      0.76      0.76       694
# weighted avg       0.77      0.77      0.77       694
#
# SNOWBALLSTEMMER
# Confusion Matrix for Support Vector Machines:
# [[211  29   8]
#  [ 37 153  29]
#  [ 14  41 172]]
# Score: 77.23
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.81      0.85      0.83       248
#            3       0.69      0.70      0.69       219
#            5       0.82      0.76      0.79       227
#
#    micro avg       0.77      0.77      0.77       694
#    macro avg       0.77      0.77      0.77       694
# weighted avg       0.77      0.77      0.77       694
#
# LEMMATIZED
# Confusion Matrix for Support Vector Machines:
# [[213  29   6]
#  [ 38 147  34]
#  [ 20  37 170]]
# Score: 76.37
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.79      0.86      0.82       248
#            3       0.69      0.67      0.68       219
#            5       0.81      0.75      0.78       227
#
#    micro avg       0.76      0.76      0.76       694
#    macro avg       0.76      0.76      0.76       694
# weighted avg       0.76      0.76      0.76       694
#
# LANCASTER
# Confusion Matrix for Support Vector Machines:
# [[209  32   7]
#  [ 33 156  30]
#  [ 13  44 170]]
# Score: 77.09
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.82      0.84      0.83       248
#            3       0.67      0.71      0.69       219
#            5       0.82      0.75      0.78       227
#
#    micro avg       0.77      0.77      0.77       694
#    macro avg       0.77      0.77      0.77       694
# weighted avg       0.77      0.77      0.77       694

# %% [markdown]
# # Gradient Boosting Classifier

# %%
# Gradient Boosting Classifier
from sklearn.ensemble import GradientBoostingClassifier

# WITH STOPWORDS #################################################################################################################

# initialization
gbi = GradientBoostingClassifier(learning_rate=0.1,max_depth=5,max_features=0.5,random_state=101)
gbi.fit(x_train_cleanWithStopwords,y_train)

# predicting
prediction = gbi.predict(x_test_cleanWithStopwords)
print("WITH STOPWORDS")
print("Confusion Matrix for Gradient Boosting Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_gbi_with_stopwords_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))

# WITHOUT STOPWORDS #################################################################################################################

# initialization
gbi = GradientBoostingClassifier(learning_rate=0.1,max_depth=5,max_features=0.5,random_state=101)
gbi.fit(x_train_cleanNoStopwords,y_train)

# predicting
prediction = gbi.predict(x_test_cleanNoStopwords)
print("WITHOUT STOPWORDS")
print("Confusion Matrix for Gradient Boosting Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_gbi_no_stopwords_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# PORTERSTEMMER #################################################################################################################

# initialization
gbi = GradientBoostingClassifier(learning_rate=0.1,max_depth=5,max_features=0.5,random_state=101)
gbi.fit(x_train_porterStemmer,y_train)

# predicting
prediction = gbi.predict(x_test_porterStemmer)
print("PORTERSTEMMER")
print("Confusion Matrix for Gradient Boosting Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_gbi_porterstemmer_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# SNOWBALLSTEMMER #################################################################################################################

# initialization
gbi = GradientBoostingClassifier(learning_rate=0.1,max_depth=5,max_features=0.5,random_state=101)
gbi.fit(x_train_snowballStemmer,y_train)

# predicting
prediction = gbi.predict(x_test_snowballStemmer)
print("PORTERSTEMMER")
print("Confusion Matrix for Gradient Boosting Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_gbi_snowballstemmer_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# LEMMATIZED #################################################################################################################

# initialization
gbi = GradientBoostingClassifier(learning_rate=0.1,max_depth=5,max_features=0.5,random_state=101)
gbi.fit(x_train_lemmatized,y_train)

# predicting
prediction = gbi.predict(x_test_lemmatized)
print("LEMMATIZED")
print("Confusion Matrix for Gradient Boosting Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_gbi_lemmatized_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))



# LANCASTER #################################################################################################################

# initialization
gbi = GradientBoostingClassifier(learning_rate=0.1,max_depth=5,max_features=0.5,random_state=101)
gbi.fit(x_train_lancaster,y_train)

# predicting
prediction = gbi.predict(x_test_lancaster)
print("LANCASTER")
print("Confusion Matrix for Gradient Boosting Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_gbi_lancaster_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))
# Out:
# WITH STOPWORDS
# Confusion Matrix for Gradient Boosting Classifier:
# [[212  27   9]
#  [ 40 144  35]
#  [ 17  41 169]]
# Score: 75.65
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.79      0.85      0.82       248
#            3       0.68      0.66      0.67       219
#            5       0.79      0.74      0.77       227
#
#    micro avg       0.76      0.76      0.76       694
#    macro avg       0.75      0.75      0.75       694
# weighted avg       0.76      0.76      0.76       694
#
# WITHOUT STOPWORDS
# Confusion Matrix for Gradient Boosting Classifier:
# [[220  20   8]
#  [ 39 143  37]
#  [ 17  43 167]]
# Score: 76.37
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.80      0.89      0.84       248
#            3       0.69      0.65      0.67       219
#            5       0.79      0.74      0.76       227
#
#    micro avg       0.76      0.76      0.76       694
#    macro avg       0.76      0.76      0.76       694
# weighted avg       0.76      0.76      0.76       694
#
# PORTERSTEMMER
# Confusion Matrix for Gradient Boosting Classifier:
# [[213  29   6]
#  [ 41 141  37]
#  [ 19  40 168]]
# Score: 75.22
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.78      0.86      0.82       248
#            3       0.67      0.64      0.66       219
#            5       0.80      0.74      0.77       227
#
#    micro avg       0.75      0.75      0.75       694
#    macro avg       0.75      0.75      0.75       694
# weighted avg       0.75      0.75      0.75       694
#
# PORTERSTEMMER
# Confusion Matrix for Gradient Boosting Classifier:
# [[217  24   7]
#  [ 40 138  41]
#  [ 16  45 166]]
# Score: 75.07
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.79      0.88      0.83       248
#            3       0.67      0.63      0.65       219
#            5       0.78      0.73      0.75       227
#
#    micro avg       0.75      0.75      0.75       694
#    macro avg       0.75      0.75      0.74       694
# weighted avg       0.75      0.75      0.75       694
#
# LEMMATIZED
# Confusion Matrix for Gradient Boosting Classifier:
# [[214  25   9]
#  [ 34 149  36]
#  [ 20  37 170]]
# Score: 76.8
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.80      0.86      0.83       248
#            3       0.71      0.68      0.69       219
#            5       0.79      0.75      0.77       227
#
#    micro avg       0.77      0.77      0.77       694
#    macro avg       0.77      0.76      0.76       694
# weighted avg       0.77      0.77      0.77       694
#
# LANCASTER
# Confusion Matrix for Gradient Boosting Classifier:
# [[216  21  11]
#  [ 35 144  40]
#  [ 21  37 169]]
# Score: 76.22
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.79      0.87      0.83       248
#            3       0.71      0.66      0.68       219
#            5       0.77      0.74      0.76       227
#
#    micro avg       0.76      0.76      0.76       694
#    macro avg       0.76      0.76      0.76       694
# weighted avg       0.76      0.76      0.76       694

# %%
# K Nearest Neighbour Algorithm
from sklearn.neighbors import KNeighborsClassifier

# WITH STOPWORDS #################################################################################################################

# initialization
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(x_train_cleanWithStopwords,y_train)

# predicting
prediction = knn.predict(x_test_cleanWithStopwords)
print("CLEANED WITH STOPWORDS")
print("Confusion Matrix for K Neighbors Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_knn_with_stopwords_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))

# WITHOUT STOPWORDS #################################################################################################################

# initialization
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(x_train_cleanNoStopwords,y_train)

# predicting
prediction = knn.predict(x_test_cleanNoStopwords)
print("WITHOUT STOPWORDS")
print("Confusion Matrix for K Neighbors Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_knn_no_stopwords_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# PORTERSTEMMER #################################################################################################################

# initialization
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(x_train_porterStemmer,y_train)

# predicting
prediction = knn.predict(x_test_porterStemmer)
print("PORTERSTEMMER")
print("Confusion Matrix for K Neighbors Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_knn_porterstemmer_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# SNOWBALLSTEMMER #################################################################################################################

# initialization
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(x_train_snowballStemmer,y_train)

# predicting
prediction = knn.predict(x_test_snowballStemmer)
print("SNOWBALLSTEMMER")
print("Confusion Matrix for K Neighbors Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_knn_snowballstemmer_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# LEMMATIZED #################################################################################################################

# initialization
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(x_train_lemmatized,y_train)

# predicting
prediction = knn.predict(x_test_lemmatized)
print("LEMMATIZED")
print("Confusion Matrix for K Neighbors Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_knn_lemmatized_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# LANCASTER #################################################################################################################

# initialization
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(x_train_lancaster,y_train)

# predicting
prediction = knn.predict(x_test_lancaster)
print("LANCASTER")
print("Confusion Matrix for K Neighbors Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_knn_lancaster_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))
# Out:
# CLEANED WITH STOPWORDS
# Confusion Matrix for K Neighbors Classifier:
# [[193  33  22]
#  [ 77 112  30]
#  [ 64  70  93]]
# Score: 57.35
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.58      0.78      0.66       248
#            3       0.52      0.51      0.52       219
#            5       0.64      0.41      0.50       227
#
#    micro avg       0.57      0.57      0.57       694
#    macro avg       0.58      0.57      0.56       694
# weighted avg       0.58      0.57      0.56       694
#
# WITHOUT STOPWORDS
# Confusion Matrix for K Neighbors Classifier:
# [[244   3   1]
#  [190  27   2]
#  [195  22  10]]
# Score: 40.49
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.39      0.98      0.56       248
#            3       0.52      0.12      0.20       219
#            5       0.77      0.04      0.08       227
#
#    micro avg       0.40      0.40      0.40       694
#    macro avg       0.56      0.38      0.28       694
# weighted avg       0.55      0.40      0.29       694
#
# PORTERSTEMMER
# Confusion Matrix for K Neighbors Classifier:
# [[242   4   2]
#  [181  31   7]
#  [181  27  19]]
# Score: 42.07
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.40      0.98      0.57       248
#            3       0.50      0.14      0.22       219
#            5       0.68      0.08      0.15       227
#
#    micro avg       0.42      0.42      0.42       694
#    macro avg       0.53      0.40      0.31       694
# weighted avg       0.52      0.42      0.32       694
#
# SNOWBALLSTEMMER
# Confusion Matrix for K Neighbors Classifier:
# [[243   3   2]
#  [182  31   6]
#  [183  25  19]]
# Score: 42.22
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.40      0.98      0.57       248
#            3       0.53      0.14      0.22       219
#            5       0.70      0.08      0.15       227
#
#    micro avg       0.42      0.42      0.42       694
#    macro avg       0.54      0.40      0.31       694
# weighted avg       0.54      0.42      0.32       694
#
# LEMMATIZED
# Confusion Matrix for K Neighbors Classifier:
# [[243   4   1]
#  [175  37   7]
#  [183  23  21]]
# Score: 43.37
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.40      0.98      0.57       248
#            3       0.58      0.17      0.26       219
#            5       0.72      0.09      0.16       227
#
#    micro avg       0.43      0.43      0.43       694
#    macro avg       0.57      0.41      0.33       694
# weighted avg       0.56      0.43      0.34       694
#
# LANCASTER
# Confusion Matrix for K Neighbors Classifier:
# [[243   3   2]
#  [180  32   7]
#  [186  24  17]]
# Score: 42.07
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.40      0.98      0.57       248
#            3       0.54      0.15      0.23       219
#            5       0.65      0.07      0.13       227
#
#    micro avg       0.42      0.42      0.42       694
#    macro avg       0.53      0.40      0.31       694
# weighted avg       0.53      0.42      0.32       694

# %% [markdown]
# # Multilayer Perceptron Classifier

# %%
# Mulilayer Perceptron Classifier
from sklearn.neural_network import MLPClassifier

# WITH STOPWORDS #################################################################################################################

# initialization
mlp = MLPClassifier()
mlp.fit(x_train_cleanWithStopwords,y_train)

# predicting
prediction = mlp.predict(x_test_cleanWithStopwords)
print("WITH STOPWORDS")
print("Confusion Matrix for Multilayer Perceptron Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_mlp_with_stopwords_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))

# WITHOUT STOPWORDS #################################################################################################################

# initialization
mlp = MLPClassifier()
mlp.fit(x_train_cleanNoStopwords,y_train)

# predicting
prediction = mlp.predict(x_test_cleanNoStopwords)
print("WITHOUT STOPWORDS")
print("Confusion Matrix for Multilayer Perceptron Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_mlp_no_stopwords_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# PORTERSTEMMER #################################################################################################################

# initialization
mlp = MLPClassifier()
mlp.fit(x_train_porterStemmer,y_train)

# predicting
prediction = mlp.predict(x_test_porterStemmer)
print("PORTERSTEMMER")
print("Confusion Matrix for Multilayer Perceptron Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_mlp_porterstemmer_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# SNOWBALLSTEMMER #################################################################################################################

# initialization
mlp = MLPClassifier()
mlp.fit(x_train_snowballStemmer,y_train)

# predicting
prediction = mlp.predict(x_test_snowballStemmer)
print("SNOWBALLSTEMMER")
print("Confusion Matrix for Multilayer Perceptron Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_mlp_snowballstemmer_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# LEMMATIZED #################################################################################################################

# initialization
mlp = MLPClassifier()
mlp.fit(x_train_lemmatized,y_train)

# predicting
prediction = mlp.predict(x_test_lemmatized)
print("LEMMATIZED")
print("Confusion Matrix for Multilayer Perceptron Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_mlp_lemmatized_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# LANCASTER #################################################################################################################

# initialization
mlp = MLPClassifier()
mlp.fit(x_train_lancaster,y_train)

# predicting
prediction = mlp.predict(x_test_lancaster)
print("LANCASTER")
print("Confusion Matrix for Multilayer Perceptron Classifier:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_mlp_lancaster_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))
# Out:
# WITH STOPWORDS
# Confusion Matrix for Multilayer Perceptron Classifier:
# [[225  18   5]
#  [ 28 149  42]
#  [  9  37 181]]
# Score: 79.97
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.86      0.91      0.88       248
#            3       0.73      0.68      0.70       219
#            5       0.79      0.80      0.80       227
#
#    micro avg       0.80      0.80      0.80       694
#    macro avg       0.79      0.79      0.79       694
# weighted avg       0.80      0.80      0.80       694
#
# WITHOUT STOPWORDS
# Confusion Matrix for Multilayer Perceptron Classifier:
# [[222  21   5]
#  [ 28 155  36]
#  [ 12  38 177]]
# Score: 79.83
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.85      0.90      0.87       248
#            3       0.72      0.71      0.72       219
#            5       0.81      0.78      0.80       227
#
#    micro avg       0.80      0.80      0.80       694
#    macro avg       0.79      0.79      0.79       694
# weighted avg       0.80      0.80      0.80       694
#
# PORTERSTEMMER
# Confusion Matrix for Multilayer Perceptron Classifier:
# [[219  24   5]
#  [ 30 157  32]
#  [ 12  35 180]]
# Score: 80.12
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.84      0.88      0.86       248
#            3       0.73      0.72      0.72       219
#            5       0.83      0.79      0.81       227
#
#    micro avg       0.80      0.80      0.80       694
#    macro avg       0.80      0.80      0.80       694
# weighted avg       0.80      0.80      0.80       694
#
# SNOWBALLSTEMMER
# Confusion Matrix for Multilayer Perceptron Classifier:
# [[219  23   6]
#  [ 28 159  32]
#  [ 14  38 175]]
# Score: 79.68
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.84      0.88      0.86       248
#            3       0.72      0.73      0.72       219
#            5       0.82      0.77      0.80       227
#
#    micro avg       0.80      0.80      0.80       694
#    macro avg       0.79      0.79      0.79       694
# weighted avg       0.80      0.80      0.80       694
#
# LEMMATIZED
# Confusion Matrix for Multilayer Perceptron Classifier:
# [[221  24   3]
#  [ 32 151  36]
#  [ 15  39 173]]
# Score: 78.53
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.82      0.89      0.86       248
#            3       0.71      0.69      0.70       219
#            5       0.82      0.76      0.79       227
#
#    micro avg       0.79      0.79      0.79       694
#    macro avg       0.78      0.78      0.78       694
# weighted avg       0.78      0.79      0.78       694
#
# LANCASTER
# Confusion Matrix for Multilayer Perceptron Classifier:
# [[218  24   6]
#  [ 26 152  41]
#  [ 14  39 174]]
# Score: 78.39
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.84      0.88      0.86       248
#            3       0.71      0.69      0.70       219
#            5       0.79      0.77      0.78       227
#
#    micro avg       0.78      0.78      0.78       694
#    macro avg       0.78      0.78      0.78       694
# weighted avg       0.78      0.78      0.78       694

# %% [markdown]
# # Logistic Regression

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression

# WITH STOPWORDS #################################################################################################################

# initialization
lrg = LogisticRegression(C=1e5, solver='saga', multi_class='multinomial', random_state = 101)
lrg.fit(x_train_cleanWithStopwords,y_train)

# predicting
prediction = lrg.predict(x_test_cleanWithStopwords)
print("WITH STOPWORDS")
print("CLEANED WITH STOPWORDS")
print("Confusion Matrix for Logistic Regression:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_lrg_with_stopwords_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))

# WITHOUT STOPWORDS #################################################################################################################

# initialization
lrg = LogisticRegression(C=1e5, solver='saga', multi_class='multinomial', random_state = 101)
lrg.fit(x_train_cleanNoStopwords,y_train)

# predicting
prediction = lrg.predict(x_test_cleanNoStopwords)
print("WITHOUT STOPWORDS")
print("CLEANED WITH STOPWORDS")
print("Confusion Matrix for Logistic Regression:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_lrg_no_stopwords_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# PORTERSTEMMER #################################################################################################################

# initialization
lrg = LogisticRegression(C=1e5, solver='saga', multi_class='multinomial', random_state = 101)
lrg.fit(x_train_porterStemmer,y_train)

# predicting
prediction = lrg.predict(x_test_porterStemmer)
print("PORTERSTEMMER")
print("CLEANED WITH STOPWORDS")
print("Confusion Matrix for Logistic Regression:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_lrg_porterstemmer_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# SNOWBALLSTEMMER #################################################################################################################

# initialization
lrg = LogisticRegression(C=1e5, solver='saga', multi_class='multinomial', random_state = 101)
lrg.fit(x_train_snowballStemmer,y_train)

# predicting
prediction = lrg.predict(x_test_snowballStemmer)
print("SNOWBALLSTEMMER")
print("CLEANED WITH STOPWORDS")
print("Confusion Matrix for Logistic Regression:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_lrg_snowballstemmer_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))


# LEMMATIZED #################################################################################################################

# initialization
lrg = LogisticRegression(C=1e5, solver='saga', multi_class='multinomial', random_state = 101)
lrg.fit(x_train_lemmatized,y_train)

# predicting
prediction = lrg.predict(x_test_lemmatized)
print("LEMMATIZED")
print("CLEANED WITH STOPWORDS")
print("Confusion Matrix for Logistic Regression:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_lrg_lemmatized_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))

# LANCASTER #################################################################################################################

# initialization
lrg = LogisticRegression(C=1e5, solver='saga', multi_class='multinomial', random_state = 101)
lrg.fit(x_train_lancaster,y_train)

# predicting
prediction = lrg.predict(x_test_lancaster)
print("LANCASTER")
print("CLEANED WITH STOPWORDS")
print("Confusion Matrix for Logistic Regression:")
confusion_mat = confusion_matrix(y_test, prediction)
print(confusion_mat)
plot = skplt.metrics.plot_confusion_matrix(y_test, prediction, normalize=True)

# generating and printing the accuracy score
acc_score = round(accuracy_score(y_test,prediction)*100,2)
print("Score:", acc_score)

# generating, printing and saving to excel format the classification report
class_rep = classification_report(y_test,prediction, output_dict=True)
df_class_rep = pd.DataFrame(class_rep)
df_class_rep.transpose()
df_class_rep.to_excel("cv_lrg_lancaster_3.xlsx")
print("Classification Report:\n", classification_report(y_test,prediction))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# WITH STOPWORDS
# CLEANED WITH STOPWORDS
# Confusion Matrix for Logistic Regression:
# [[213  28   7]
#  [ 26 155  38]
#  [ 11  36 180]]
# Score: 78.96
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.85      0.86      0.86       248
#            3       0.71      0.71      0.71       219
#            5       0.80      0.79      0.80       227
#
#    micro avg       0.79      0.79      0.79       694
#    macro avg       0.79      0.79      0.79       694
# weighted avg       0.79      0.79      0.79       694
#
# WITHOUT STOPWORDS
# CLEANED WITH STOPWORDS
# Confusion Matrix for Logistic Regression:
# [[219  22   7]
#  [ 30 148  41]
#  [ 11  40 176]]
# Score: 78.24
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.84      0.88      0.86       248
#            3       0.70      0.68      0.69       219
#            5       0.79      0.78      0.78       227
#
#    micro avg       0.78      0.78      0.78       694
#    macro avg       0.78      0.78      0.78       694
# weighted avg       0.78      0.78      0.78       694
#
# PORTERSTEMMER
# CLEANED WITH STOPWORDS
# Confusion Matrix for Logistic Regression:
# [[214  28   6]
#  [ 25 154  40]
#  [ 14  36 177]]
# Score: 78.53
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.85      0.86      0.85       248
#            3       0.71      0.70      0.70       219
#            5       0.79      0.78      0.79       227
#
#    micro avg       0.79      0.79      0.79       694
#    macro avg       0.78      0.78      0.78       694
# weighted avg       0.78      0.79      0.79       694
#
# SNOWBALLSTEMMER
# CLEANED WITH STOPWORDS
# Confusion Matrix for Logistic Regression:
# [[213  27   8]
#  [ 25 153  41]
#  [ 13  39 175]]
# Score: 77.95
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.85      0.86      0.85       248
#            3       0.70      0.70      0.70       219
#            5       0.78      0.77      0.78       227
#
#    micro avg       0.78      0.78      0.78       694
#    macro avg       0.78      0.78      0.78       694
# weighted avg       0.78      0.78      0.78       694
#
# LEMMATIZED
# CLEANED WITH STOPWORDS
# Confusion Matrix for Logistic Regression:
# [[213  29   6]
#  [ 32 145  42]
#  [ 11  38 178]]
# Score: 77.23
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.83      0.86      0.85       248
#            3       0.68      0.66      0.67       219
#            5       0.79      0.78      0.79       227
#
#    micro avg       0.77      0.77      0.77       694
#    macro avg       0.77      0.77      0.77       694
# weighted avg       0.77      0.77      0.77       694
#
# LANCASTER
# CLEANED WITH STOPWORDS
# Confusion Matrix for Logistic Regression:
# [[209  34   5]
#  [ 22 160  37]
#  [ 13  41 173]]
# Score: 78.1
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.86      0.84      0.85       248
#            3       0.68      0.73      0.70       219
#            5       0.80      0.76      0.78       227
#
#    micro avg       0.78      0.78      0.78       694
#    macro avg       0.78      0.78      0.78       694
# weighted avg       0.78      0.78      0.78       694
